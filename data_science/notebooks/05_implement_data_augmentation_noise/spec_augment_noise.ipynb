# %%
import matplotlib.pylab as plt 
import warnings
import pandas as pd
import os

from librosa import display
from processing import preprocessing, data_augmentation

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
warnings.filterwarnings("ignore")

# %%
data_df = pd.read_json('/datasets/UrbanSound8K/processed/mean_mfcc_data.json')
data_df = preprocessing.filter_mfccs(data_df)

# %%
i = 1
print(data_df.label.iloc[i])
display.specshow(data_df.feature.iloc[i], x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.show()
# Out:
# children_playing

# %%
i = 1
print(data_df.label.iloc[i])
display.specshow(data_df.feature.iloc[i], x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.show()
print(data_df.feature.iloc[i])
print(data_df.label.iloc[i])
display.specshow(data_augmentation.noise(data_df.feature.iloc[i]), x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.show()
print(data_augmentation.noise(data_df.feature.iloc[i]))
# Out:
# children_playing
# [[-468.03671265 -467.42263794 -481.04653931 ... -453.07138062
#   -459.75082397 -462.15719604]
#  [ 111.13384247  115.84701538  118.69844055 ...  122.39273834
#    121.24326324  121.32119751]
#  [ -27.87674522  -31.86744118  -41.55286407 ...  -49.09509277
#    -44.7819519   -43.52590942]
#  ...
#  [   2.50141263    1.06106019    1.11127591 ...    6.52355862
#      9.5570116     9.0902729 ]
#  [  -3.4088037    -2.09407234    2.62400103 ...   11.62059021
#     13.20365429   15.47078037]
#  [ -13.65251637  -11.09328079   -4.3113389  ...    1.54352474
#      0.95444238   -1.39218163]]
# children_playing
# [[-468.16187462 -467.70641092 -481.26936265 ... -453.02195536
#   -459.85258023 -462.23627166]
#  [ 111.11147603  115.8717487   118.7625186  ...  122.24570377
#    121.20147238  121.46320644]
#  [ -27.82305247  -31.80591018  -41.5544876  ...  -49.27620034
#    -44.63034535  -43.60518712]
#  ...
#  [   2.51336768    1.06041469    1.12462481 ...    6.56799314
#      9.5964597     9.23475889]
#  [  -3.47242547   -2.09930427    2.63507197 ...   11.65283484
#     12.99822433   15.60979653]
#  [ -13.59056553  -11.03156488   -4.2151913  ...    1.47497416
#      1.0337457    -1.50918319]]
